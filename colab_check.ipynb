# %%
import os
print(os.getcwd())         # should print /content/... not C:\Users\...
# Out:
# /content

# %%
import torch
print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# PyTorch: 2.11.0+cu128
# CUDA available: True
# GPU name: Tesla T4

# %%
# !pip show torch transformers langchain chromadb sentence-transformers 2>/dev/null | grep -E "Name|Version"
# Out:
# Name: torch
# Version: 2.11.0+cu128
# Name: transformers
# Version: 5.12.1
# Name: langchain
# Version: 1.3.11
# Name: sentence-transformers
# Version: 5.6.0
