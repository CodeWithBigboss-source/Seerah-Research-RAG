# %%
import os

REPO = "https://github.com/CodeWithBigboss-source/Seerah-Research-RAG.git"
PROJECT_NAME = "Seerah-Research-RAG"
PROJECT_PATH = f"/content/{PROJECT_NAME}"

# Clone only if not already cloned
if not os.path.exists(PROJECT_PATH):
    # !git clone {REPO}

# Always navigate using absolute path — never relative
# %cd {PROJECT_PATH}

# Pull latest code
# !git pull

print("Current directory:", os.getcwd())
print("Files here:", os.listdir("."))
# Out:
# /content/Seerah-Research-RAG
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 1), reused 3 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 556 bytes | 556.00 KiB/s, done.
# From https://github.com/CodeWithBigboss-source/Seerah-Research-RAG
#    1addeaf..65abf2e  main       -> origin/main
# Updating 1addeaf..65abf2e
# Fast-forward
#  requirements-colab.txt | 20 +++++++++++---------
#  1 file changed, 11 insertions(+), 9 deletions(-)
# Current directory: /content/Seerah-Research-RAG
# Files here: ['Seerah-Research-RAG', '.gitignore', '.git', 'main.py', 'requirements-colab.txt', 'colab_check.ipynb', 'requirements-local.txt', 'tester.ipynb']

# %%
# !pip install -q -r requirements-colab.txt

# %%
import torch, transformers, langchain, sentence_transformers, chromadb

print(f"torch:                 {torch.__version__}")
print(f"CUDA:                  {torch.cuda.is_available()}")
print(f"GPU:                   {torch.cuda.get_device_name(0)}")
print(f"transformers:          {transformers.__version__}")
print(f"langchain:             {langchain.__version__}")
print(f"sentence-transformers: {sentence_transformers.__version__}")
print(f"chromadb:              {chromadb.__version__}")
print("\nAll good. Ready to build.")
# Out:
# torch:                 2.11.0+cu128
# CUDA:                  True
# GPU:                   Tesla T4
# transformers:          5.12.1
# langchain:             1.3.11
# sentence-transformers: 5.6.0
# chromadb:              1.4.0
#
# All good. Ready to build.

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !python datasets/download_datasets.py
# Out:
# python3: can't open file '/content/Seerah-Research-RAG/datasets/download_datasets.py': [Errno 2] No such file or directory

# %%
# %cd /content/Seerah-Research-RAG
# !git pull
print(os.listdir("."))
# Out:
# /content/Seerah-Research-RAG
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 1), reused 6 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 2.95 KiB | 2.96 MiB/s, done.
# From https://github.com/CodeWithBigboss-source/Seerah-Research-RAG
#    65abf2e..66596eb  main       -> origin/main
# Updating 65abf2e..66596eb
# Fast-forward
#  .gitignore                    |  12 +++-
#  colab_setup.ipynb             | 162 ++++++++++++++++++++++++++++++++++++++++++
#  datasets/download_datasets.py |  95 +++++++++++++++++++++++++
#  3 files changed, 267 insertions(+), 2 deletions(-)
#  create mode 100644 colab_setup.ipynb
#  create mode 100644 datasets/download_datasets.py
# ['Seerah-Research-RAG', '.gitignore', 'colab_setup.ipynb', '.git', 'datasets', 'main.py', 'requirements-colab.txt', 'colab_check.ipynb', 'requirements-local.txt', 'tester.ipynb']

# %%
# !python datasets/download_datasets.py
# Out:
# ...
# DATASET 1: Hadith Collections
# ...
# README.md: 100% 4.38k/4.38k [00:00<00:00, 13.6MB/s]
# Jami%60%20at-Tirmidhi.json: 100% 9.45M/9.45M [00:00<00:00, 148MB/s]
# Sahih Muslim.json: 100% 14.8M/14.8M [00:01<00:00, 12.4MB/s]
# Sahih al-Bukhari.json: 100% 16.2M/16.2M [00:00<00:00, 16.8MB/s]
# Sunan%20Abi%20Dawud.json: 100% 9.86M/9.86M [00:00<00:00, 24.2MB/s]
# Sunan%20Ibn%20Majah.json: 100% 6.90M/6.90M [00:00<00:00, 140MB/s]
# Sunan%20an-Nasa%27i.json: 100% 10.1M/10.1M [00:00<00:00, 51.2MB/s]
# Generating train split: 100% 33738/33738 [00:01<00:00, 18838.14 examples/s]
# Splits:        ['train']
# Total entries: 33738
# Columns:       ['Book', 'Chapter_Number', 'Chapter_Title_Arabic', 'Chapter_Title_English', 'Arabic_Text', 'English_Text', 'Grade', 'Reference', 'In-book reference']
#
# Sample entry:
#   Book                          : Jami` at-Tirmidhi
#   Chapter_Number                : 1
#   Chapter_Title_Arabic          : باب مَا جَاءَ لاَ تُقْبَلُ صَلاَةٌ بِغَيْرِ طُهُورٍ  ‏
# ...
